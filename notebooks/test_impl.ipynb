# %%
from data.datasets_from_labs.read_data import read_earthquake_dataset
from src.LogRegCCD import LogRegCCD
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
X, y = read_earthquake_dataset(filepath='../data/datasets_from_labs/earthquake.txt')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2137)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
lambda_vals = np.logspace(-3, 1, 10)

# %%
logreg = LogRegCCD(0.1)
logreg.fit(X_train, y_train)
# Out:
# Iteration 1
# Log-Likelihood: -5.968998
# Intercept: -0.782609
# Coefficients: [ 1.20481738 -0.99424129]
#
# Iteration 2
# Log-Likelihood: -3.685800
# Intercept: -1.336891
# Coefficients: [ 1.92810016 -1.48290592]
#
# Iteration 3
# Log-Likelihood: -2.659852
# Intercept: -1.813170
# Coefficients: [ 2.49115871 -1.90616174]
#
# Iteration 4
# Log-Likelihood: -2.069656
# Intercept: -2.214618
# Coefficients: [ 2.99466298 -2.28360774]
#
# Iteration 5
# Log-Likelihood: -1.697706
# Intercept: -2.564350
# Coefficients: [ 3.4464818  -2.61485931]
#
# Iteration 6
# Log-Likelihood: -1.451076
# Intercept: -2.872963
# Coefficients: [ 3.84671248 -2.90075808]
#
# Iteration 7
# Log-Likelihood: -1.280553
# Intercept: -3.144800
# Coefficients: [ 4.19755783 -3.14508819]
#
# Iteration 8
# Log-Likelihood: -1.158240
# Intercept: -3.382596
# Coefficients: [ 4.50290581 -3.3529887 ]
#
# Iteration 9
# Log-Likelihood: -1.067721
# Intercept: -3.589189
# Coefficients: [ 4.76734686 -3.52963737]
#
# Iteration 10
# ...

# %%
logreg.predict_proba(X_test)
# Out:
# array([7.00795531e-04, 9.99987531e-01, 1.51344351e-07, 1.18757803e-05,
#        8.81956525e-01, 4.62448728e-07])

# %%
logreg.validate(X_train, y_train, measure="f1")
# Out:
# 1.0

# %%
logreg.validate(X_test, y_test, measure="f1")
# Out:
# 1.0

# %%
logreg.plot_coeff() # I know this plot sucks

# %%
accuracy = logreg.validate(X_train, y_train, measure="f1")
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.0
# /media/marta/Dane/Sem8/LogRegCCD/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
logreg.predict_proba(X_test)
# Out:
# array([0.38541822, 0.38541822, 0.38541822, 0.38541822, 0.38541822,
#        0.38541822])

# %%
X_test, y_test
# Out:
# (array([[-0.45406094, -0.26058074],
#         [-0.68581365,  0.36654304],
#         [-1.52855075, -0.29193693],
#         [-0.87542949, -0.00973123],
#         [-0.26444509,  1.41697537],
#         [-0.24337666, -0.15083408]]),
#  5     0
#  16    0
#  7     0
#  14    0
#  8     0
#  3     0
#  Name: popn, dtype: int64)

# %%
logreg.plot_likelihoods()
