# %%
from data.datasets_from_labs.read_data import read_haberman_dataset
from src.LogRegCCD import LogRegCCD
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 4
#       1 import sys
#       2 sys.path.append('../')  # Adjust the path to include the parent directory of 'data'
# ----> 4 from data.datasets_from_labs.read_data import read_haberman_dataset
#       5 from src.LogRegCCD import LogRegCCD
#       6 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'data.datasets_from_labs'

# %%
X, y = read_haberman_dataset(filepath='../data/datasets_from_labs/haberman.data')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2871)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
lambda_vals = np.logspace(-3, 1, 10)

# %%
model = LogRegCCD(lambda_vals=lambda_vals, max_iter=1000, stop_tol=1e-6)
model.fit(X_train, y_train)
# Out:
# Iteration 1
# Log-Likelihood: -128.274597
# Intercept: 1.016393
# Coefficients: [ 0.02322807  0.00116677 -0.48239144]
#
# Iteration 2
# Log-Likelihood: -127.535313
# Intercept: 1.162131
# Coefficients: [-0.01171823  0.00476181 -0.57623607]
#
# Iteration 3
# Log-Likelihood: -127.524942
# Intercept: 1.171614
# Coefficients: [-0.01846079  0.00638306 -0.5949023 ]
#
# Iteration 4
# Log-Likelihood: -127.524851
# Intercept: 1.171798
# Coefficients: [-0.01996515  0.00682597 -0.59621808]
#
# Iteration 5
# Log-Likelihood: -127.524850
# Intercept: 1.171802
# Coefficients: [-0.02009833  0.00686153 -0.59624979]
#
# Iteration 6
# Log-Likelihood: -127.524850
# Intercept: 1.171802
# Coefficients: [-0.02010346  0.00686254 -0.59625055]
#
# Iteration 7
# Log-Likelihood: -127.524850
# Intercept: 1.171802
# Coefficients: [-0.02010359  0.00686256 -0.59625057]
#
# Converged at iteration 6
# Iteration 1
# Log-Likelihood: -128.274664
# Intercept: 1.016393
# Coefficients: [ 0.02319885  0.00114011 -0.48236474]
#
# Iteration 2
# Log-Likelihood: -127.535363
# Intercept: 1.162129
# Coefficients: [-0.01167425  0.00471868 -0.57619109]
#
# Iteration 3
# Log-Likelihood: -127.524948
# Intercept: 1.171609
# Coefficients: [-0.01841083  0.00633561 -0.59485474]
#
# Iteration 4
# Log-Likelihood: -127.524852
# Intercept: 1.171794
# Coefficients: [-0.01991435  0.00677804 -0.59617017]
#
# Iteration 5
# Log-Likelihood: -127.524851
# Intercept: 1.171797
# Coefficients: [-0.02004746  0.00681357 -0.59620185]
#
# Iteration 6
# Log-Likelihood: -127.524851
# Intercept: 1.171797
# Coefficients: [-0.02005258  0.00681457 -0.59620261]
#
# Iteration 7
# Log-Likelihood: -127.524851
# Intercept: 1.171797
# Coefficients: [-0.02005272  0.0068146  -0.59620263]
#
# Converged at iteration 6
# Iteration 1
# Log-Likelihood: -128.274853
# Intercept: 1.016393
# Coefficients: [ 0.02311754  0.00106593 -0.48229044]
#
# Iteration 2
# Log-Likelihood: -127.535503
# Intercept: 1.162121
# Coefficients: [-0.01155186  0.00459867 -0.57606596]
#
# Iteration 3
# Log-Likelihood: -127.524967
# Intercept: 1.171596
# Coefficients: [-0.01827182  0.00620358 -0.59472244]
#
# Iteration 4
# Log-Likelihood: -127.524855
# Intercept: 1.171780
# Coefficients: [-0.01977301  0.00664467 -0.59603685]
#
# Iteration 5
# Log-Likelihood: -127.524853
# Intercept: 1.171783
# Coefficients: [-0.01990591  0.00668011 -0.59606847]
#
# Iteration 6
# Log-Likelihood: -127.524853
# Intercept: 1.171783
# Coefficients: [-0.01991102  0.00668112 -0.59606923]
#
# Iteration 7
# Log-Likelihood: -127.524853
# Intercept: 1.171783
# Coefficients: [-0.01991116  0.00668114 -0.59606925]
#
# Converged at iteration 6
# Iteration 1
# Log-Likelihood: -128.275383
# Intercept: 1.016393
# Coefficients: [ 0.02289128  0.00085951 -0.48208368]
#
# Iteration 2
# Log-Likelihood: -127.535902
# Intercept: 1.162100
# Coefficients: [-0.01121135  0.00426474 -0.57571782]
#
# Iteration 3
# Log-Likelihood: -127.525031
# Intercept: 1.171559
# Coefficients: [-0.01788505  0.00583624 -0.5943544 ]
#
# Iteration 4
# Log-Likelihood: -127.524874
# Intercept: 1.171742
# Coefficients: [-0.01937976  0.0062736  -0.59566601]
#
# Iteration 5
# Log-Likelihood: -127.524870
# Intercept: 1.171746
# Coefficients: [-0.01951208  0.00630882 -0.59569748]
#
# Iteration 6
# Log-Likelihood: -127.524869
# Intercept: 1.171746
# Coefficients: [-0.01951716  0.00630982 -0.59569823]
#
# Iteration 7
# Log-Likelihood: -127.524869
# Intercept: 1.171746
# Coefficients: [-0.0195173   0.00630984 -0.59569825]
#
# Converged at iteration 6
# Iteration 1
# Log-Likelihood: -128.276892
# Intercept: 1.016393
# Coefficients: [ 2.22617026e-02  2.85137615e-04 -4.81508376e-01]
#
# Iteration 2
# Log-Likelihood: -127.537081
# Intercept: 1.162041
# Coefficients: [-0.01026406  0.00333567 -0.57474954]
#
# Iteration 3
# Log-Likelihood: -127.525288
# Intercept: 1.171458
# Coefficients: [-0.01680902  0.00481436 -0.59333121]
#
# Iteration 4
# Log-Likelihood: -127.525011
# Intercept: 1.171639
# Coefficients: [-0.01828576  0.0052414  -0.59463514]
#
# Iteration 5
# Log-Likelihood: -127.524999
# Intercept: 1.171642
# Coefficients: [-0.01841649  0.00527601 -0.59466619]
#
# Iteration 6
# Log-Likelihood: -127.524998
# Intercept: 1.171642
# Coefficients: [-0.0184215   0.00527698 -0.59466692]
#
# Iteration 7
# Log-Likelihood: -127.524998
# Intercept: 1.171642
# Coefficients: [-0.01842163  0.005277   -0.59466694]
#
# Converged at iteration 6
# Iteration 1
# Log-Likelihood: -128.281223
# Intercept: 1.016393
# Coefficients: [ 0.02050987  0.         -0.47990215]
#
# Iteration 2
# Log-Likelihood: -127.540826
# Intercept: 1.161872
# Coefficients: [-0.00773556  0.0007584  -0.57207101]
#
# Iteration 3
# Log-Likelihood: -127.526625
# Intercept: 1.171181
# Coefficients: [-0.01381775  0.00197331 -0.59049093]
#
# Iteration 4
# Log-Likelihood: -127.526026
# Intercept: 1.171356
# Coefficients: [-0.01524366  0.00237169 -0.59177455]
#
# Iteration 5
# Log-Likelihood: -127.525995
# Intercept: 1.171359
# Coefficients: [-0.01537006  0.00240464 -0.59180444]
#
# Iteration 6
# Log-Likelihood: -127.525993
# Intercept: 1.171359
# Coefficients: [-0.01537485  0.00240555 -0.59180512]
#
# Iteration 7
# Log-Likelihood: -127.525993
# Intercept: 1.171359
# Coefficients: [-0.01537497  0.00240557 -0.59180513]
#
# Converged at iteration 6
# Iteration 1
# Log-Likelihood: -128.294671
# Intercept: 1.016393
# Coefficients: [ 0.0156353   0.         -0.47542948]
#
# Iteration 2
# Log-Likelihood: -127.552872
# Intercept: 1.161356
# Coefficients: [-0.00077722  0.         -0.56473381]
#
# Iteration 3
# Log-Likelihood: -127.532725
# Intercept: 1.170417
# Coefficients: [-0.00601538  0.         -0.58277672]
#
# Iteration 4
# Log-Likelihood: -127.531512
# Intercept: 1.170581
# Coefficients: [-0.00726517  0.         -0.58400251]
#
# Iteration 5
# Log-Likelihood: -127.531459
# Intercept: 1.170584
# Coefficients: [-0.00735443  0.         -0.5840276 ]
#
# Iteration 6
# Log-Likelihood: -127.531458
# Intercept: 1.170584
# Coefficients: [-0.00735627  0.         -0.58402797]
#
# Iteration 7
# Log-Likelihood: -127.531458
# Intercept: 1.170584
# Coefficients: [-0.0073563   0.         -0.58402798]
#
# Converged at iteration 6
# Iteration 1
# Log-Likelihood: -128.343391
# Intercept: 1.016393
# Coefficients: [ 0.00207152  0.         -0.46298399]
#
# Iteration 2
# Log-Likelihood: -127.584664
# Intercept: 1.159607
# Coefficients: [ 0.          0.         -0.54583684]
#
# Iteration 3
# Log-Likelihood: -127.554863
# Intercept: 1.168288
# Coefficients: [ 0.          0.         -0.56278015]
#
# Iteration 4
# Log-Likelihood: -127.553451
# Intercept: 1.168441
# Coefficients: [ 0.          0.         -0.56385342]
#
# Iteration 5
# Log-Likelihood: -127.553429
# Intercept: 1.168443
# Coefficients: [ 0.          0.         -0.56387055]
#
# Iteration 6
# Log-Likelihood: -127.553429
# Intercept: 1.168443
# Coefficients: [ 0.          0.         -0.56387075]
#
# Converged at iteration 5
# Iteration 1
# Log-Likelihood: -128.571067
# Intercept: 1.016393
# Coefficients: [ 0.          0.         -0.42541275]
#
# Iteration 2
# Log-Likelihood: -127.746351
# Intercept: 1.154656
# Coefficients: [ 0.          0.         -0.49500352]
#
# Iteration 3
# Log-Likelihood: -127.685114
# Intercept: 1.162426
# Coefficients: [ 0.          0.         -0.51019783]
#
# Iteration 4
# Log-Likelihood: -127.681771
# Intercept: 1.162557
# Coefficients: [ 0.          0.         -0.51112248]
#
# Iteration 5
# Log-Likelihood: -127.681720
# Intercept: 1.162559
# Coefficients: [ 0.          0.         -0.51113674]
#
# Iteration 6
# Log-Likelihood: -127.681720
# Intercept: 1.162559
# Coefficients: [ 0.          0.         -0.51113691]
#
# Converged at iteration 5
# Iteration 1
# Log-Likelihood: -129.583934
# Intercept: 1.016393
# Coefficients: [ 0.         0.        -0.3203933]
#
# Iteration 2
# Log-Likelihood: -128.709996
# Intercept: 1.141625
# Coefficients: [ 0.          0.         -0.36485827]
#
# Iteration 3
# Log-Likelihood: -128.591166
# Intercept: 1.147418
# Coefficients: [ 0.          0.         -0.37632703]
#
# Iteration 4
# Log-Likelihood: -128.585210
# Intercept: 1.147502
# Coefficients: [ 0.          0.         -0.37692175]
#
# Iteration 5
# Log-Likelihood: -128.585129
# Intercept: 1.147503
# Coefficients: [ 0.          0.         -0.37692984]
#
# Iteration 6
# Log-Likelihood: -128.585128
# Intercept: 1.147503
# Coefficients: [ 0.          0.         -0.37692992]
#
# Converged at iteration 5

# %%
model.validate_and_plot_all(X_test, y_test)

# %%
model.plot_coeff()

# %%
model.plot_likelihoods()
